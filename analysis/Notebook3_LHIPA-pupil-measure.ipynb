# %%
import pandas as pd
import scipy.stats as stats
from constants import questions

# %%
allData = pd.read_csv("LHIPA.csv")

# %%
def addQuestionInfo(allData,questions):
    
    #change the type of questionID to integer
    allData['task'] = allData['task'].astype('int')
    
    #extend the columns of questionnaireData with those in DataFrame(questions) based the common question ID
    allData = allData.merge(pd.DataFrame(questions), left_on=['task'], right_on=['id'])
    
    
    return allData

# %%
#Add question info
allDataWithQs = addQuestionInfo(allData,questions)
#print(allDataWithQs.shape)
allDataWithQs
# Out:
#      Unnamed: 0     LHIPA participant  task  id  \
# 0             0  1.436563     SP10-no     7   7
# 1             0  0.800090      SP2-no     7   7
# 2             0  1.368287     SP14-no     7   7
# 3             0  1.465562      SP6-no     7   7
# 4             0  1.425710     SP15-no     7   7
# ..          ...       ...         ...   ...  ..
# 611           0  0.830783      KP5-no    46  46
# 612           0  0.786943     KP18-no    46  46
# 613           0  0.778445      KP4-no    46  46
# 614           0  0.722764     KP19-no    46  46
# 615           0       NaN     SP20-no    46  46
#
#                                               question             type  \
# 0     The activity "Enter container information fro...  multiple-choice
# 1     The activity "Enter container information fro...  multiple-choice
# 2     The activity "Enter container information fro...  multiple-choice
# 3     The activity "Enter container information fro...  multiple-choice
# 4     The activity "Enter container information fro...  multiple-choice
# ..                                                 ...              ...
# 611   If the "Container" object is in state "[tempo...  multiple-choice
# 612   If the "Container" object is in state "[tempo...  multiple-choice
# 613   If the "Container" object is in state "[tempo...  multiple-choice
# 614   If the "Container" object is in state "[tempo...  multiple-choice
# 615   If the "Container" object is in state "[tempo...  multiple-choice
#
#                      options model-group ExpectedAnswer   Type1         Type2  \
# 0    True;False;I don't know           1          False   Local  Control-flow
# 1    True;False;I don't know           1          False   Local  Control-flow
# 2    True;False;I don't know           1          False   Local  Control-flow
# 3    True;False;I don't know           1          False   Local  Control-flow
# 4    True;False;I don't know           1          False   Local  Control-flow
# ..                       ...         ...            ...     ...           ...
# 611  True;False;I don't know           1           True  Global     Data-flow
# 612  True;False;I don't know           1           True  Global     Data-flow
# 613  True;False;I don't know           1           True  Global     Data-flow
# 614  True;False;I don't know           1           True  Global     Data-flow
# 615  True;False;I don't know           1           True  Global     Data-flow
#
#                   Type3
# 0              Ordering
# 1              Ordering
# 2              Ordering
# 3              Ordering
# 4              Ordering
# ..                  ...
# 611  Data-based Routing
# 612  Data-based Routing
# 613  Data-based Routing
# 614  Data-based Routing
# 615  Data-based Routing
#
# [616 rows x 13 columns]

# %%
#Remove SP20 + all questions for a participant (local + global!) if either local or global is nan:
#KP16 --> Ordering
#SP20 --> all
#SP11 --> Exclusivness
#SP2 --> Repetition + Concurrency

measureAllData_new = allDataWithQs.drop(allDataWithQs[allDataWithQs['participant'] == 'SP20-no'].index)

measureAllData_new = measureAllData_new.drop(allDataWithQs[(allDataWithQs['participant'] == 'KP16-no') & (allDataWithQs['Type3'] == 'Ordering')].index)
measureAllData_new = measureAllData_new.drop(allDataWithQs[(allDataWithQs['participant'] == 'SP11-no') & (allDataWithQs['Type3'] == 'Exclusiveness')].index)
measureAllData_new = measureAllData_new.drop(allDataWithQs[(allDataWithQs['participant'] == 'SP2-no') & (allDataWithQs['Type3'] == 'Repetition')].index)
measureAllData_new = measureAllData_new.drop(allDataWithQs[(allDataWithQs['participant'] == 'SP2-no') & (allDataWithQs['Type3'] == 'Concurrency')].index)

# %%
#Select control-flow question type
measureAllData_new = measureAllData_new.loc[(measureAllData_new['Type2'] == 'Control-flow')]

# %%
#Check whether the LHIPA is always larger for global than for local tasks for each participant on average
LHIPAPartCompare = measureAllData_new.groupby(['participant','Type1','Type2'],as_index=False).agg({'LHIPA':'mean'})
LHIPAPartCompare_G = LHIPAPartCompare.loc[LHIPAPartCompare['Type1'] == 'Global']
LHIPAPartCompare_L = LHIPAPartCompare.loc[LHIPAPartCompare['Type1'] == 'Local']
LHIPAPartCompare_G_L = pd.merge(LHIPAPartCompare_G, LHIPAPartCompare_L, on='participant')

LHIPAPartCompare_G_L['Glo > Loc'] = LHIPAPartCompare_G_L.apply(lambda x: True if x['LHIPA_x'] < x['LHIPA_y'] else (x['LHIPA_x'],x['LHIPA_y']), axis=1)
LHIPAPartCompare_G_L
# Out:
#    participant Type1_x       Type2_x   LHIPA_x Type1_y       Type2_y  \
# 0       KP1-no  Global  Control-flow  0.998822   Local  Control-flow
# 1      KP10-no  Global  Control-flow  0.715306   Local  Control-flow
# 2      KP11-no  Global  Control-flow  1.116338   Local  Control-flow
# 3      KP12-no  Global  Control-flow  1.133361   Local  Control-flow
# 4      KP13-no  Global  Control-flow  0.560528   Local  Control-flow
# 5      KP14-no  Global  Control-flow  0.598355   Local  Control-flow
# 6      KP15-no  Global  Control-flow  0.307933   Local  Control-flow
# 7      KP16-no  Global  Control-flow  0.627983   Local  Control-flow
# 8      KP17-no  Global  Control-flow  0.654586   Local  Control-flow
# 9      KP18-no  Global  Control-flow  0.734753   Local  Control-flow
# 10     KP19-no  Global  Control-flow  0.713067   Local  Control-flow
# 11      KP2-no  Global  Control-flow  0.742960   Local  Control-flow
# 12     KP20-no  Global  Control-flow  1.005109   Local  Control-flow
# 13     KP21-no  Global  Control-flow  0.903390   Local  Control-flow
# 14     KP22-no  Global  Control-flow  1.094449   Local  Control-flow
# 15     KP23-no  Global  Control-flow  0.699699   Local  Control-flow
# 16     KP24-no  Global  Control-flow  0.730885   Local  Control-flow
# 17      KP3-no  Global  Control-flow  0.931167   Local  Control-flow
# 18      KP4-no  Global  Control-flow  0.723740   Local  Control-flow
# 19      KP5-no  Global  Control-flow  0.940024   Local  Control-flow
# 20      KP6-no  Global  Control-flow  1.102913   Local  Control-flow
# 21      KP7-no  Global  Control-flow  0.794333   Local  Control-flow
# 22      KP8-no  Global  Control-flow  0.515858   Local  Control-flow
# 23      KP9-no  Global  Control-flow  0.325236   Local  Control-flow
# 24      SP1-no  Global  Control-flow  0.887305   Local  Control-flow
# 25     SP10-no  Global  Control-flow  1.077324   Local  Control-flow
# 26     SP11-no  Global  Control-flow  0.758963   Local  Control-flow
# 27     SP12-no  Global  Control-flow  0.727749   Local  Control-flow
# 28     SP13-no  Global  Control-flow  0.830178   Local  Control-flow
# 29     SP14-no  Global  Control-flow  1.313953   Local  Control-flow
# 30     SP15-no  Global  Control-flow  0.696412   Local  Control-flow
# 31     SP16-no  Global  Control-flow  0.698709   Local  Control-flow
# 32     SP17-no  Global  Control-flow  0.897438   Local  Control-flow
# 33     SP18-no  Global  Control-flow  1.072079   Local  Control-flow
# 34     SP19-no  Global  Control-flow  0.718236   Local  Control-flow
# 35      SP2-no  Global  Control-flow  0.695111   Local  Control-flow
# 36      SP3-no  Global  Control-flow  0.630452   Local  Control-flow
# 37      SP4-no  Global  Control-flow  0.746737   Local  Control-flow
# 38      SP5-no  Global  Control-flow  1.109621   Local  Control-flow
# 39      SP6-no  Global  Control-flow  0.852439   Local  Control-flow
# 40      SP7-no  Global  Control-flow  0.736773   Local  Control-flow
# 41      SP8-no  Global  Control-flow  1.100975   Local  Control-flow
# 42      SP9-no  Global  Control-flow  0.838176   Local  Control-flow
#
#      LHIPA_y                                   Glo > Loc
# 0   0.977516     (0.9988215244161478, 0.977515936997543)
# 1   1.522794                                        True
# 2   1.083964     (1.1163382563947728, 1.083963735696072)
# 3   1.565494                                        True
# 4   1.064391                                        True
# 5   1.091184                                        True
# 6   0.654738                                        True
# 7   1.287151                                        True
# 8   1.121428                                        True
# 9   0.938462                                        True
# 10  1.437801                                        True
# 11  1.273007                                        True
# 12  1.155290                                        True
# 13  1.036064                                        True
# 14  1.395549                                        True
# 15  1.108759                                        True
# 16  1.124190                                        True
# 17  1.330356                                        True
# 18  1.122247                                        True
# 19  1.477704                                        True
# 20  1.236490                                        True
# 21  1.373481                                        True
# 22  0.433887    (0.5158576585802139, 0.4338867994508638)
# 23  0.120685  (0.32523629696451295, 0.12068474738808393)
# 24  1.258199                                        True
# 25  1.494829                                        True
# 26  1.537787                                        True
# 27  1.092004                                        True
# 28  1.388508                                        True
# 29  1.443110                                        True
# 30  1.352335                                        True
# 31  1.458293                                        True
# 32  1.043425                                        True
# 33  1.472921                                        True
# 34  1.419810                                        True
# 35  0.730718                                        True
# 36  1.092576                                        True
# 37  1.496743                                        True
# 38  1.388296                                        True
# 39  1.227857                                        True
# 40  1.089259                                        True
# 41  0.924773      (1.10097460688403, 0.9247734516918349)
# 42  1.111046                                        True

# %%
#LHIPA

# %%
#calculate mean per participant
LHIPAPart = measureAllData_new.groupby(['participant','Type1','Type2'],as_index=False).agg({'LHIPA':'mean'})
#calculate descriptives
LHIPAPart.groupby(['Type1']).agg({'LHIPA':'mean'})
# Out:
#            LHIPA
# Type1
# Global  0.815335
# Local   1.185003

# %%
LHIPAPart.groupby(['Type1']).agg({'LHIPA':'std'})
# Out:
#            LHIPA
# Type1
# Global  0.215667
# Local   0.297898

# %%
#Inferentials
#Control-flow
lhipa_participant = measureAllData_new.groupby(['participant', 'Type1', 'Type2'],as_index=False).agg({'LHIPA':'mean'})
lhipa_participant = lhipa_participant.reset_index()
#print(lhipa_participant)

lhipa_Global = lhipa_participant.loc[(lhipa_participant["Type1"]=='Global')][['participant','LHIPA']]
lhipa_Local = lhipa_participant.loc[(lhipa_participant["Type1"]=='Local')][['participant','LHIPA']]
print(len(lhipa_Global), len(lhipa_Local))

measure_GL_merge = lhipa_Global.merge(lhipa_Local, on=['participant'], suffixes=('_global', '_local'), how='inner')

print(stats.wilcoxon(measure_GL_merge['LHIPA_global'], measure_GL_merge['LHIPA_local'],alternative='less'))
# Out:
# 43 43
# WilcoxonResult(statistic=29.0, pvalue=1.9770141079789028e-10)
